# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Seaborn

# %% [markdown]
# #### Quand faut-il l'utiliser ?
# ![image.png](attachment:image.png)

# %% [markdown]
# Site internet seaborn: https://seaborn.pydata.org/index.html

# %% [markdown]
# Fonctionnement des fonctions seaborn: ![image.png](attachment:image.png)

# %%
iris = pd.read_csv("../data/iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Affiche toutes les relations entre variables(toutes les possibilités de scatterplot)
#Les histogrammes des variables sont affichés sur la diagonale
sns.pairplot(iris)

# %%
#Affiche les relations entre variables en coloriant les points selon la serie "species"
sns.pairplot(iris, hue="Species")

# %% [markdown]
# Découvertes de fonctions seaborn

# %%
#Télécharge le dataset du titanic faisant partie de seaborn
titanic = sns.load_dataset('titanic')
display(titanic.head())
titanic.drop(['alone', 'alive', 'who', 'adult_male', 'embark_town', 'class'], axis=1, inplace=True)
titanic.dropna (axis=0, inplace=True)
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 1          1       1  female  38.0      1      0  71.2833        C    C
# ...

# %%
sns.pairplot(titanic, hue="survived")

# %%
#Permet de visualiser la distribution d'une variable continue selon une variable catégorielle
sns.catplot(x="pclass", y="age", data=titanic, hue="sex")
#Permet de terminer une figure
plt.show()
#Affiche un graphique en boite à moustaches
sns.boxplot(x="pclass", y="age", data=titanic, hue="sex")
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
#Crée un graphique de la densité de population en fonction du tarif
sns.distplot(titanic["fare"])
# Out:
# C:\Users\32472\AppData\Local\Temp\ipykernel_14308\3721446479.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic["fare"])
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.jointplot(x="age", y="fare", data=titanic)
plt.show()
sns.jointplot(x="age", y="fare", data=titanic, kind="hex")
plt.show()
sns.jointplot(x="age", y="fare", data=titanic, kind="kde")

# %%
#Il faut d'abord exclure les données string
titanic_numeric = titanic.select_dtypes(include=['float64', 'int64'])
#Affiche un graphique de colération entre les variables
sns.heatmap(titanic_numeric.corr())
plt.show()
